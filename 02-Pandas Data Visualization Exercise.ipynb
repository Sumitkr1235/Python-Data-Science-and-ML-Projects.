# %% [markdown]
# ___
#
# <a href='http://www.pieriandata.com'> <img src='../Pierian_Data_Logo.png' /></a>
# ___
# # Pandas Data Visualization Exercise
#
# This is just a quick exercise for you to review the various plots we showed earlier. Use **df3** to replicate the following plots.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df3 = pd.read_csv('df3')
# %matplotlib inline

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 4 columns):
# a    500 non-null float64
# b    500 non-null float64
# c    500 non-null float64
# d    500 non-null float64
# dtypes: float64(4)
# memory usage: 15.8 KB

# %%
df3.head()
# Out:
#           a         b         c         d
# 0  0.336272  0.325011  0.001020  0.401402
# 1  0.980265  0.831835  0.772288  0.076485
# 2  0.480387  0.686839  0.000575  0.746758
# 3  0.502106  0.305142  0.768608  0.654685
# 4  0.856602  0.171448  0.157971  0.321231

# %%
df3.mean().plot.pie()

# %%
df3.sum().plot.pie()

# %%
df3['a'].head().plot.pie()

# %%
df3.head().plot.pie(y=['a','b'])

# %%
df3.head().sum().plot.pie(y=['a','b','c'],subplots=True)
#only one column so y and subplota not working
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001E90CD52388>],
#       dtype=object)

# %%
df3.head().plot.pie(y=['a','b','c'])

# %%
df3.head().plot.pie(y=['a','b','c'],subplots=True)
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))

# %% [markdown]
# ** Recreate this scatter plot of b vs a. Note the color and size of the points. Also note the figure size. See if you can figure out how to stretch it in a similar fashion. Remeber back to your matplotlib lecture...**

# %%
df3.plot.scatter(x='a',y='b',figsize=(12,3),c='r',marker='o',s=50)
#plt.plot(markersize)
#fig=plt.figure(figsize=(12,4))
#ax=fig.add_axes([0,0,1,1])
#ax.scatter(x=df['a'],y=df['b'],color='red',marker='o')
#ax.plot(markersize=10,mew=4,mec='black')

# %% [markdown]
# ** Create a histogram of the 'a' column.**

# %%
df3['a'].plot.hist(bins=10,color='b')
#sns.set_style('ticks')

# %% [markdown]
# ** These plots are okay, but they don't look very polished. Use style sheets to set the style to 'ggplot' and redo the histogram from above. Also figure out how to add more bins to it.***

# %%
plt.style.use('ggplot')

# %%
df3['a'].plot.hist(bins=25,color='r',alpha=0.5)
#sns.set_style('darkgrid')

# %% [markdown]
# ** Create a boxplot comparing the a and b columns.**

# %%
df3[['a','b']].plot.box()

# %%
df=pd.DataFrame(df3,columns=['a','b'])
df.plot.box()

# %% [markdown]
# ** Create a kde plot of the 'd' column **

# %%
df3['d'].plot.kde(color='red')

# %% [markdown]
# ** Figure out how to increase the linewidth and make the linestyle dashed. (Note: You would usually not dash a kde plot line)**

# %%
df3['d'].plot.kde(color='red',ls='--',lw=4,alpha=0.65)

# %% [markdown]
# ** Create an area plot of all the columns for just the rows up to 30. (hint: use .ix).**

# %%
df3.ix[0:30].plot.area(alpha=0.5)
# Out:
# C:\Users\HP\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.

# %%
df3.ix[0:30]
# Out:
# C:\Users\HP\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# 17  0.202699  0.103978  0.342236  0.787626
# 18  0.185218  0.751554  0.612737  0.088429
# 19  0.842810  0.842357  0.206589  0.389940
# 20  0.844033  0.449981  0.132198  0.103938
# 21  0.163878  0.112354  0.219087  0.059327
# 22  0.331902  0.808027  0.510172  0.387539
# 23  0.501642  0.941300  0.323753  0.690911
# 24  0.371520  0.876331  0.144358  0.594585
# 25  0.994329  0.414772  0.440280  0.547651
# 26  0.006800  0.460372  0.091869  0.551726
# 27  0.203857  0.308069  0.240756  0.980957
# 28  0.605779  0.380764  0.792923  0.891649
# 29  0.477304  0.183489  0.866535  0.201154
# 30  0.556262  0.127413  0.566897  0.375828

# %%
df3.iloc[0:31,0:4]
# Out:
#            a         b         c         d
# 0   0.336272  0.325011  0.001020  0.401402
# 1   0.980265  0.831835  0.772288  0.076485
# 2   0.480387  0.686839  0.000575  0.746758
# 3   0.502106  0.305142  0.768608  0.654685
# 4   0.856602  0.171448  0.157971  0.321231
# 5   0.705973  0.632689  0.504017  0.313622
# 6   0.166724  0.269734  0.608569  0.874427
# 7   0.054041  0.966440  0.065596  0.109448
# 8   0.757839  0.523885  0.527210  0.226936
# 9   0.425383  0.213701  0.049020  0.287598
# 10  0.176837  0.166534  0.779374  0.936486
# 11  0.221546  0.660821  0.811782  0.392565
# 12  0.001350  0.450186  0.076469  0.753368
# 13  0.537323  0.623779  0.071851  0.751200
# 14  0.032284  0.050182  0.897562  0.614129
# 15  0.488804  0.091374  0.203803  0.179708
# 16  0.821116  0.191407  0.756962  0.592383
# 17  0.202699  0.103978  0.342236  0.787626
# 18  0.185218  0.751554  0.612737  0.088429
# 19  0.842810  0.842357  0.206589  0.389940
# 20  0.844033  0.449981  0.132198  0.103938
# 21  0.163878  0.112354  0.219087  0.059327
# 22  0.331902  0.808027  0.510172  0.387539
# 23  0.501642  0.941300  0.323753  0.690911
# 24  0.371520  0.876331  0.144358  0.594585
# 25  0.994329  0.414772  0.440280  0.547651
# 26  0.006800  0.460372  0.091869  0.551726
# 27  0.203857  0.308069  0.240756  0.980957
# 28  0.605779  0.380764  0.792923  0.891649
# 29  0.477304  0.183489  0.866535  0.201154
# 30  0.556262  0.127413  0.566897  0.375828

# %%
df3.head(n=30).plot.area(alpha=0.5)

# %% [markdown]
# ## Bonus Challenge!
# Note, you may find this really hard, reference the solutions if you can't figure it out!
# ** Notice how the legend in our previous figure overlapped some of actual diagram. Can you figure out how to display the legend outside of the plot as shown below?**
#
# ** Try searching Google for a good stackoverflow link on this topic. If you can't find it on your own - [use this one for a hint.](http://stackoverflow.com/questions/23556153/how-to-put-legend-outside-the-plot-with-pandas)**

# %%
#f=plt.figure()
df3.head(n=30).plot.area(alpha=0.3)
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
#plt.show()

# %% [markdown]
# # Great Job!
